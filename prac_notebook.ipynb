# %%
from prac_ingestion import getCrimeData

# Target forces
targetForces = ["metropolitan", "thames", "surrey", "sussex"]

masterDf = getCrimeData(
    forces=targetForces,
    basePath=r"C:\Users\noahe\Documents\Rockborne\Advance\2025crime",
)

# Inspect the result
masterDf.head()
# Out:
# Successfully loaded 1303098 records across 24 files.
#                                             Crime ID    Month  \
# 0  4af53e255f9f3e69d1a295a288fe02488234842b18020e...  2025-01
# 1  af818ffc133013b72feaea4adead5a76c76aee204b98d4...  2025-01
# 2                                                NaN  2025-01
# 3                                                NaN  2025-01
# 4                                                NaN  2025-01
#
#                    Reported by                 Falls within  Longitude  \
# 0  Metropolitan Police Service  Metropolitan Police Service  -0.549537
# 1  Metropolitan Police Service  Metropolitan Police Service   0.884518
# 2  Metropolitan Police Service  Metropolitan Police Service   0.142112
# 3  Metropolitan Police Service  Metropolitan Police Service   0.140194
# 4  Metropolitan Police Service  Metropolitan Police Service   0.140194
#
#     Latitude                   Location  LSOA code                  LSOA name  \
# ...

# %%
from prac_ingestion import cleaningValidation

cleanedDf = cleaningValidation(masterDf)

cleanedDf.head()
# Out:
# There are 1303098 values in the dataset before any processing at all
# There are 115345 duplicate rows.
# There are 1303098 values in the dataset after removing duplicates
#
# List of null values in every column before handling null values
#  Crime ID                  148056
# Month                          0
# Reported by                    0
# Falls within                   0
# Longitude                   5562
# Latitude                    5562
# Location                       0
# LSOA code                   5562
# LSOA name                   5562
# Crime type                     0
# Last outcome category     148056
# Context                  1187753
# dtype: int64
#
#
# List of null values in every column
#  Crime ID                 0
# Month                    0
# Reported by              0
# Falls within             0
# Longitude                0
# Latitude                 0
# Location                 0
# LSOA code                0
# LSOA name                0
# ...

# %%
from feature_engineering_transformation import yearConversion, textStandard
yearConvertedDf = yearConversion(cleanedDf)
yearConvertedDf.head()
textStandardDf = textStandard(yearConvertedDf)

textStandardDf.head()
# Out:
# Crime ID
# Month
# Longitude
# Latitude
# Location
# LSOA code
# LSOA name
# Crime type
# Last outcome category
# Year
# Force
#                                             Crime ID    Month  Longitude  \
# 0  4af53e255f9f3e69d1a295a288fe02488234842b18020e...  2025-01  -0.549537
# 1  af818ffc133013b72feaea4adead5a76c76aee204b98d4...  2025-01   0.884518
# 2                                        No Crime ID  2025-01   0.142112
# 3                                        No Crime ID  2025-01   0.140194
# 6                                        No Crime ID  2025-01   0.138830
#
#     Latitude                   Location  LSOA code                  LSOA name  \
# 0  50.815808      On or near Peel Close  E01031427                  Arun 004A
# 1  51.128775  On or near East Stour Way  E01032817               Ashford 009G
# 2  51.589389           On or near A1112  E01000027  Barking and Dagenham 001A
# 3  51.582356     On or near Hatch Grove  E01000027  Barking and Dagenham 001A
# ...
